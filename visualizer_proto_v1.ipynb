# %% [raw]
# ---
# title: Flood Prediction Visualizer
# description: Flood predictor v1
# params:
#     queryDt:
#         input: text
#         label: timestamp
#         value: 170714135400
# show-code: True
# ---

# %%
queryDt='170714135400'

# %%
# !pip install arm-pyart
# !pip install matplotlib
# Out:
# Collecting arm-pyart
#   Downloading arm_pyart-1.12.6.tar.gz (43.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 59.9 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xarray>=0.21.1
#   Downloading xarray-2022.3.0-py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.9/870.9 kB 79.5 MB/s eta 0:00:00
# Collecting pooch
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 12.6 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 56.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting s3fs
#   Downloading s3fs-2022.5.0-py3-none-any.whl (27 kB)
# Collecting netCDF4
#   Downloading netCDF4-1.6.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 86.8 MB/s eta 0:00:003 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/nlim/miniconda3/lib/python3.8/site-packages (from arm-pyart) (1.22.3)
# Collecting cftime>=1.6.0
#   Downloading cftime-1.6.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 46.5 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 77.6 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Collecting Cython
#   Using cached Cython-0.29.30-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Collecting fsspec
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from xarray>=0.21.1->arm-pyart) (21.3)
# Requirement already satisfied: pandas>=1.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from xarray>=0.21.1->arm-pyart) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib->arm-pyart) (9.2.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 78.5 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib->arm-pyart) (3.0.9)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib->arm-pyart) (2.8.2)
# Requirement already satisfied: requests>=2.19.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from pooch->arm-pyart) (2.28.1)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting aiohttp<=4
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.4 MB/s eta 0:00:00
# Collecting aiobotocore~=2.3.0
#   Downloading aiobotocore-2.3.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 12.4 MB/s eta 0:00:00
# Collecting wrapt>=1.10.10
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 16.8 MB/s eta 0:00:00
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.10.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.24.22,>=1.24.21
#   Downloading botocore-1.24.21-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 93.5 MB/s eta 0:00:0031m116.7 MB/s eta 0:00:01
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from aiohttp<=4->s3fs->arm-pyart) (2.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.7/158.7 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from aiohttp<=4->s3fs->arm-pyart) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 14.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 kB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from pandas>=1.1->xarray>=0.21.1->arm-pyart) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/nlim/miniconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->arm-pyart) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->pooch->arm-pyart) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nlim/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->pooch->arm-pyart) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/nlim/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->pooch->arm-pyart) (3.3)
# Requirement already satisfied: typing_extensions>=4.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from aioitertools>=0.5.1->aiobotocore~=2.3.0->s3fs->arm-pyart) (4.3.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: arm-pyart
#   Building wheel for arm-pyart (pyproject.toml) ... done
#   Created wheel for arm-pyart: filename=arm_pyart-1.12.6-cp38-cp38-linux_x86_64.whl size=9828805 sha256=f3fbfcec128cea1a6d252b4453f9a1d2e9e86b58b2e8f5b9c334fce61a798ecf
#   Stored in directory: /home/nlim/.cache/pip/wheels/2d/0f/15/b23a2604d02114135b980abdb27752b26e8e85b53c13ee857c
# Successfully built arm-pyart
# Installing collected packages: appdirs, wrapt, scipy, multidict, kiwisolver, jmespath, fsspec, frozenlist, fonttools, Cython, cycler, cftime, async-timeout, aioitertools, yarl, pooch, netCDF4, matplotlib, botocore, aiosignal, xarray, aiohttp, aiobotocore, s3fs, arm-pyart
# Successfully installed Cython-0.29.30 aiobotocore-2.3.4 aiohttp-3.8.1 aioitertools-0.10.0 aiosignal-1.2.0 appdirs-1.4.4 arm-pyart-1.12.6 async-timeout-4.0.2 botocore-1.24.21 cftime-1.6.1 cycler-0.11.0 fonttools-4.34.4 frozenlist-1.3.0 fsspec-2022.5.0 jmespath-1.0.1 kiwisolver-1.4.3 matplotlib-3.5.2 multidict-6.0.2 netCDF4-1.6.0 pooch-1.6.0 s3fs-2022.5.0 scipy-1.8.1 wrapt-1.14.1 xarray-2022.3.0 yarl-1.7.2
# Requirement already satisfied: matplotlib in /home/nlim/miniconda3/lib/python3.8/site-packages (3.5.2)
# Requirement already satisfied: numpy>=1.17 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/nlim/miniconda3/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /home/nlim/miniconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import glob
import numpy as np
import re
import pyart
import matplotlib.pyplot as plt
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:10: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _nlv = LooseVersion(_np_version)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   np_version_under1p17 = _nlv < LooseVersion("1.17")
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:12: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   np_version_under1p18 = _nlv < LooseVersion("1.18")
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p19 = _nlv < LooseVersion("1.19")
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:14: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p20 = _nlv < LooseVersion("1.20")
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/function.py:120: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(__version__) >= LooseVersion("1.17.0"):
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/pandas/compat/numpy/function.py:120: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(__version__) >= LooseVersion("1.17.0"):
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/matplotlib/__init__.py:169: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# /home/nlim/miniconda3/envs/pyradar/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
def find_nearest(array,value):
    array=np.asarray(array)
    idx=(np.abs(array-value)).argmin()
    return array[idx]

def find_nearest_idx(array,value):
    array=np.asarray(array)
    idx=(np.abs(array-value)).argmin()
    return idx


aklFiles=glob.glob('/media/nlim/My Passport/nz_radar/*/*/AKL*.RAWSURV')
aklList=[]
for file in aklFiles:
    m=re.search('(\\d+).RAWSURV',file)
    aklList.append(int(m.group(1)))

bopFiles=glob.glob('/media/nlim/My Passport/nz_radar/*/*/BOP*.RAWSURV')
bopList=[]
for file in bopFiles:
    m=re.search('(\\d+).RAWSURV',file)
    bopList.append(int(m.group(1)))

reflectance=[]
enddt=int(queryDt)
startdt=int(queryDt)-100

startIdx=find_nearest_idx(aklList,startdt)
endIdx=find_nearest_idx(aklList,enddt)

# %%
myMa=[]
for fileNo in range(endIdx,endIdx+1):
        akldt=aklList[fileNo]
        print(akldt)
        aklMonth=str(akldt)[2:4]
        aklYear=str(2000+int(str(akldt)[0:2]))
        bopdt=str(find_nearest(bopList,akldt))
        bopMonth=str(bopdt)[2:4]
        bopYear=str(2000+int(str(bopdt)[0:2]))
        file1='/media/nlim/My Passport/nz_radar/'+aklYear+'/'+aklMonth+'/AKL'+str(akldt)+'.RAWSURV'
        file2='/media/nlim/My Passport/nz_radar/'+bopYear+'/'+bopMonth+'/BOP'+str(bopdt)+'.RAWSURV'
        radar_files=[file1, file2]
        radars = [pyart.io.read(file) for file in radar_files]
        filters = []
        for radar in radars:
            gatefilter = pyart.correct.despeckle.despeckle_field(radar, 'reflectivity',
                                                         threshold=-100, size=20)
            gatefilter.exclude_transition()
            gatefilter.exclude_above('reflectivity', 80)
            filters.append(gatefilter)           
        grid = pyart.map.grid_from_radars(radars, gatefilters=filters,
                                  grid_shape= (5, 250, 350),
                                  grid_limits= ([0.0, 10000.0], [-25000.0, 25000.0], [-35000.0, 35000.0]),
                                  fields=['reflectivity'],
                                  max_refl= 80.,
                                  copy_field_data= True,
                                  grid_origin= (-37.0428, 175.6819),
                                  roi_func= 'dist_beam',
                                  min_radius= 500.0,
                                  h_factor= 1.0,
                                  nb= 1.0,
                                  bsp= 1.0
                                 )                               
        myMa.append(grid.fields['reflectivity']['data'][0,:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1590885/533269604.py in <module>
#       1 myMa=[]
# ----> 2 for fileNo in range(endIdx,endIdx+1):
#       3         akldt=aklList[fileNo]
#       4         print(akldt)
#       5         aklMonth=str(akldt)[2:4]
#
# NameError: name 'endIdx' is not defined

# %%
import pandas as pd
df_pred=pd.read_csv(f'batchmode/bayesianTest/csvOut/bayesian_LSTM_6hr_epoch_80_alpha_200_opitonui.csv')
flood_index=np.abs(df_pred['gt'].to_numpy())>0.15
pred=df_pred['pred']
gt=df_pred['gt']
pred_sd=df_pred['pred_sd']
df = pd.read_csv('merged_full.csv')
dtStr=str(queryDt)
year=2000+int(dtStr[0:2])
mont=str(int(dtStr[2:4])).zfill(2)
day=str(int(dtStr[4:6])).zfill(2)
hr=str(int(dtStr[6:8])).zfill(2)
min=str(int(dtStr[8:10])).zfill(2)
sec=str(int(dtStr[10:12])).zfill(2)
dfSrch=f'{year}-{mont}-{day} {hr}:{min}:{sec}+00:00'
dfIndex=df.datetimeUTC.searchsorted(dfSrch)-1
lookback=int(3*24*60/15)
tairua=df['Tairua'][dfIndex:dfIndex+lookback]
actualDT=df['datetimeUTC'][dfIndex:dfIndex+lookback]
opitonui=df['Opitonui'][dfIndex:dfIndex+lookback]
crrain=df['CR Rain'][dfIndex:dfIndex+lookback]
pinnacles=df['Pinnacles Rain'][dfIndex:dfIndex+lookback]
predictionWindow=int(12*60/15)
df_pred2=df_pred.reindex(range(len(df_pred)+dfIndex+lookback))
df_pred2=df_pred.shift(dfIndex+lookback)
df_pred2=df_pred
df_pred2=df_pred2.reindex(range(len(df_pred)+dfIndex+lookback))
df_pred2=df_pred2.shift(dfIndex+lookback)
pred=df_pred2['pred'][dfIndex+lookback:dfIndex+lookback+predictionWindow]
pred_sd=df_pred2['pred_sd'][dfIndex+lookback:dfIndex+lookback+predictionWindow]
pred=pred*3+1.3
pred_sd=pred_sd*3

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

fig = plt.figure(figsize=(20, 16))
main_grid=fig.add_gridspec(2, 1, wspace=0.1, hspace=0.1)
radar_grid = main_grid[0, 0].subgridspec(1, 2, wspace=0.4, hspace=0.05)
radar_ax=fig.add_subplot(radar_grid[0])
map_ax=fig.add_subplot(radar_grid[1])
#ts_grid= main_grid[1, 0].subgridspec(3, 1, wspace=0.2, hspace=0.15,height_ratios=[2,1,1])
ts_grid= main_grid[1, 0].subgridspec(1, 2, wspace=0.2, hspace=0.15,width_ratios=[2,1])
ts_grid2= ts_grid[0, 1].subgridspec(2, 1, wspace=0.2, hspace=0.15,height_ratios=[1,1])

pred_ax=fig.add_subplot(ts_grid[0])
rain_ax=fig.add_subplot(ts_grid2[0])
river_ax=fig.add_subplot(ts_grid2[1])

import matplotlib.image as mpimg
tauranga=mpimg.imread('tauranga.png')
def init():
      global radar_ax, im, im_base
      im_base=radar_ax.imshow(tauranga)
      im=radar_ax.imshow(myMa[0],cmap='ocean', alpha=0.7)
      #im.set_data(np.zeros(myMa[0].shape))

def animate(n):
    im.set_data(myMa[n])
    return
init()
#ani=animation.FuncAnimation(fig,animate, frames=104, interval=120, blit=False)
map_ax.imshow(tauranga)
map_ax.plot([225,275],[175,120],lw=4,color='lime')
map_ax.plot([130,175],[225,200],lw=4,color='lime')

rain_ax.plot(crrain)
rain_ax.set_xlim([dfIndex,dfIndex+lookback+predictionWindow])
rain_ax.set_ylim([0,3])

river_ax.plot(pinnacles)
river_ax.set_xlim([dfIndex,dfIndex+lookback+predictionWindow])
river_ax.set_ylim([0,3])

pred_ax.plot(tairua)
pred_ax.set_xlim([dfIndex,dfIndex+lookback+predictionWindow])
pred_ax.set_ylim([0,5])

pred_ax.plot(pred,color='orange')
pred_ax.plot(pred+2*pred_sd,':',color='orange')
pred_ax.plot(pred-2*pred_sd,':',color='orange')

#plt.show()
